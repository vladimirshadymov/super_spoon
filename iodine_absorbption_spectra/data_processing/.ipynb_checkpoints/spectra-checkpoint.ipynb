# %% [markdown]
# # Спектры поглощения йода

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('30_480_655.dat', sep=' ').iloc[:,:2].copy()
df1 = df1.rename(index=str, columns={'Wavelength': 'Wavelength, nm', 'Trans': 'Transmittance, %'})
df1 = df1.iloc[1:,:].copy()
df1 = df1.astype('float', copy=True)
df1
# Out:
#      Wavelength, nm  Transmittance, %
# 1             480.0         59.468811
# 2             480.2         59.323908
# 3             480.4         58.694676
# 4             480.6         58.972310
# 5             480.8         59.616889
# 6             481.0         59.628546
# 7             481.2         59.627211
# 8             481.4         59.767693
# 9             481.6         59.347259
# 10            481.8         58.640355
# 11            482.0         59.509833
# 12            482.2         59.693046
# 13            482.4         59.393252
# 14            482.6         59.356091
# 15            482.8         59.667109
# 16            483.0         58.912709
# 17            483.2         58.945352
# 18            483.4         58.727095
# 19            483.6         58.847942
# 20            483.8         59.112423
# 21            484.0         59.030459
# 22            484.2         58.538968
# 23            484.4         58.100717
# 24            484.6         58.413437
# ...

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
plt.figure()
df1.plot(x='Wavelength, nm', y='Transmittance, %', label='70$^0C$')
plt.xlabel('Wavelength, nm')
plt.ylabel('Transmittance, %')
plt.grid(True)
